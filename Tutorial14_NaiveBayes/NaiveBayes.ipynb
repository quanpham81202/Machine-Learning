# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis = 'columns', inplace = True)

# %%
df
# Out:
#      Pclass     Sex   Age     Fare  Survived
# 0         3    male  22.0   7.2500         0
# 1         1  female  38.0  71.2833         1
# 2         3  female  26.0   7.9250         1
# 3         1  female  35.0  53.1000         1
# 4         3    male  35.0   8.0500         0
# ..      ...     ...   ...      ...       ...
# 886       2    male  27.0  13.0000         0
# 887       1  female  19.0  30.0000         1
# 888       3  female   NaN  23.4500         0
# 889       1    male  26.0  30.0000         1
# 890       3    male  32.0   7.7500         0
#
# [891 rows x 5 columns]

# %%
dummy_variables = pd.get_dummies(df.Sex)

# %%
dummy_variables
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
merged = pd.concat([df, dummy_variables], axis = 'columns')

# %%
merged
# Out:
#      Pclass     Sex   Age     Fare  Survived  female  male
# 0         3    male  22.0   7.2500         0       0     1
# 1         1  female  38.0  71.2833         1       1     0
# 2         3  female  26.0   7.9250         1       1     0
# 3         1  female  35.0  53.1000         1       1     0
# 4         3    male  35.0   8.0500         0       0     1
# ..      ...     ...   ...      ...       ...     ...   ...
# 886       2    male  27.0  13.0000         0       0     1
# 887       1  female  19.0  30.0000         1       1     0
# 888       3  female   NaN  23.4500         0       1     0
# 889       1    male  26.0  30.0000         1       0     1
# 890       3    male  32.0   7.7500         0       0     1
#
# [891 rows x 7 columns]

# %%
new_df = merged.drop(['Sex'], axis = 'columns')

# %%
new_df
# Out:
#      Pclass   Age     Fare  Survived  female  male
# 0         3  22.0   7.2500         0       0     1
# 1         1  38.0  71.2833         1       1     0
# 2         3  26.0   7.9250         1       1     0
# 3         1  35.0  53.1000         1       1     0
# 4         3  35.0   8.0500         0       0     1
# ..      ...   ...      ...       ...     ...   ...
# 886       2  27.0  13.0000         0       0     1
# 887       1  19.0  30.0000         1       1     0
# 888       3   NaN  23.4500         0       1     0
# 889       1  26.0  30.0000         1       0     1
# 890       3  32.0   7.7500         0       0     1
#
# [891 rows x 6 columns]

# %%
new_df['Age'] = new_df['Age'].fillna(new_df['Age'].mean())

# %%
new_df
# Out:
#      Pclass        Age     Fare  Survived  female  male
# 0         3  22.000000   7.2500         0       0     1
# 1         1  38.000000  71.2833         1       1     0
# 2         3  26.000000   7.9250         1       1     0
# 3         1  35.000000  53.1000         1       1     0
# 4         3  35.000000   8.0500         0       0     1
# ..      ...        ...      ...       ...     ...   ...
# 886       2  27.000000  13.0000         0       0     1
# 887       1  19.000000  30.0000         1       1     0
# 888       3  29.699118  23.4500         0       1     0
# 889       1  26.000000  30.0000         1       0     1
# 890       3  32.000000   7.7500         0       0     1
#
# [891 rows x 6 columns]

# %%
X = new_df.drop(['Survived'], axis = 'columns')

# %%
y = new_df.Survived

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.8044692737430168
