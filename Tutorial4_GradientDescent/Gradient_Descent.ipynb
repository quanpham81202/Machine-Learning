# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import math

# %%
def predict_data():
    df = pd.read_csv("test_scores.csv")
    reg = linear_model.LinearRegression()
    reg.fit(df[['math']], df.cs)
    return reg.coef_, reg.intercept_

# %%
# y = mx + b

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.001
    cost_previous = 0
    for i in range(iterations):
        y_predicted = m_curr*x + b_curr
        cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate*md
        b_curr = b_curr - learning_rate*bd
        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
        cost_previous = cost
        print("m {}, b {}, iteration {}".format(m_curr,b_curr,i))
    return m_curr, b_curr

# %%
if __name__ == "__main__":
    df = pd.read_csv("test_scores.csv")
    x = np.array(df.math)
    y = np.array(df.cs)

    m, b = gradient_descent(x,y)
    print("Using gradient descent function: Coef {} Intercept {}".format(m, b))

    m_sklearn, b_sklearn = predict_data()
    print("Using sklearn: Coef {} Intercept {}".format(m_sklearn,b_sklearn))
# Out:
# m 9.891800000000002, b 0.1398, iteration 0
# m -73.89063968000005, b -1.0422240800000002, iteration 1
# m 635.7369779473285, b 8.971449829408007, iteration 2
# m -5374.727514955187, b -75.84115332401389, iteration 3
# m 45533.21677472461, b 642.5139249806472, iteration 4
# m -385651.2277087454, b -5441.869063972523, iteration 5
# m 3266431.5217446033, b 46092.15849604381, iteration 6
# m -27666290.14670837, b -390395.13732602727, iteration 7
# m 234330311.64447328, b 3306602.156348863, iteration 8
# m -1984750831.161688, b -28006540.543865472, iteration 9
# m 16810611721.985636, b 237212183.72022378, iteration 10
# m -142383951599.6276, b -2009159966.5646977, iteration 11
# m 1205975725927.0713, b 17017354287.21848, iteration 12
# m -10214475965673.32, b -144135037405.07288, iteration 13
# m 86515438918328.9, b 1220807221683.833, iteration 14
# m -732775836605216.4, b -10340097032248.14, iteration 15
# m 6206527221336492.0, b 87579434932273.39, iteration 16
# m -5.256857312278437e+16, b -741787760708146.4, iteration 17
# m 4.4524978004856864e+17, b 6282857184017264.0, iteration 18
# m -3.771214527171064e+18, b -5.3215079144839544e+16, iteration 19
# m 3.194175415065832e+19, b 4.507256118435043e+17, iteration 20
# m -2.70542991089517e+20, b -3.817594193908135e+18, iteration 21
# m 2.2914680791303368e+21, b 3.2334584604039156e+19, iteration 22
# m -1.9408471594578794e+22, b -2.73870219936982e+20, iteration 23
# m 1.6438752652427682e+23, b 2.319649325538619e+21, iteration 24
# m -1.3923434797574683e+24, b -1.9647163516755844e+22, iteration 25
# m 1.179298944763208e+25, b 1.6640921970587552e+23, iteration 26
# m -9.98852669143012e+25, b -1.4094669889371823e+24, iteration 27
# m 8.460167450200246e+26, b 1.1938023604791333e+25, iteration 28
# m -7.165664716783168e+27, b -1.0111368957709355e+26, iteration 29
# m 6.069235761064736e+28, b 8.564213439642921e+26, iteration 30
# m -5.140573021385156e+29, b -7.253790475506124e+27, iteration 31
# m 4.354006340916478e+30, b 6.143877267115057e+28, iteration 32
# m -3.6877933914909612e+31, b -5.203793520206333e+29, iteration 33
# m 3.1235186707288454e+32, b 4.4075533777153323e+30, iteration 34
# m -2.645584459504449e+33, b -3.733147116997748e+31, iteration 35
# m 2.2407796687631987e+34, b 3.161932755621568e+32, iteration 36
# m -1.897914657724828e+35, b -2.6781207484566015e+33, iteration 37
# m 1.6075119290933782e+36, b 2.268337532024402e+34, iteration 38
# m -1.3615441514505511e+37, b -1.9212558515727185e+35, iteration 39
# m 1.153212267230097e+38, b 1.627281652350979e+36, iteration 40
# m -9.767575527192004e+38, b -1.378288880114782e+37, iteration 41
# m 8.273024350370022e+39, b 1.1673948601973964e+38, iteration 42
# m -7.00715665942656e+40, b -9.88770046161735e+38, iteration 43
# m 5.934981255984084e+41, b 8.374768790924474e+39, iteration 44
# m -5.026860996677788e+42, b -7.093333032660473e+40, iteration 45
# m 4.2576935612799155e+43, b 6.00797165490201e+41, iteration 46
# m -3.606217572704928e+44, b -5.088683026710746e+42, iteration 47
# m 3.054424888618902e+45, b 4.3100561110680525e+43, iteration 48
# m -2.5870628191789245e+46, b -3.650568051310261e+44, iteration 49
# m 2.1912125111723684e+47, b 3.0919892349022796e+45, iteration 50
# m -1.8559318442225447e+48, b -2.6188793892830366e+46, iteration 51
# m 1.571952967974059e+49, b 2.2181607808308733e+47, iteration 52
# m -1.3314261195607527e+50, b -1.878756719286422e+48, iteration 53
# m 1.127702639941742e+51, b 1.5912853751483807e+49, iteration 54
# m -9.551511912287871e+51, b -1.347800446522359e+50, iteration 55
# m 8.090020948721924e+52, b 1.1415715069187284e+51, iteration 56
# m -6.852154878910969e+53, b -9.6689796235876e+51, iteration 57
# m 5.8036965271395205e+54, b 8.189514751791012e+52, iteration 58
# m -4.915664338352587e+55, b -6.936424988029658e+53, iteration 59
# m 4.1635112680953706e+56, b 5.875072342233698e+54, iteration 60
# m -3.526446251488082e+57, b -4.976118834420492e+55, iteration 61
# m 2.9868594952363866e+58, b 4.214715532312912e+56, iteration 62
# m -2.5298357065612897e+59, b -3.569815675510983e+57, iteration 63
# m 2.1427418036903485e+60, b 3.023592899549887e+58, iteration 64
# m -1.814877711376367e+61, b -2.560948478355227e+59, iteration 65
# m 1.5371805887102158e+62, b 2.169093964258975e+60, iteration 66
# m -1.301974313473436e+63, b -1.837197688883803e+61, iteration 67
# m 1.1027572982605405e+64, b 1.556085353449907e+62, iteration 68
# m -9.340227731702466e+64, b -1.3179864322017813e+63, iteration 69
# m 7.911065673079069e+65, b 1.1163193790217116e+64, iteration 70
# m -6.70058181465373e+66, b -9.455096998969969e+64, iteration 71
# m 5.675315881607841e+67, b 8.008358623880182e+65, iteration 72
# m -4.806927405257671e+68, b -6.782987827164836e+66, iteration 73
# m 4.071412333945906e+69, b 5.745112828273199e+67, iteration 74
# m -3.4484395114592517e+70, b -4.866044617890066e+68, iteration 75
# m 2.920788681864644e+71, b 4.1214839344441324e+69, iteration 76
# m -2.4738744860566226e+72, b -3.49084958231364e+70, iteration 77
# m 2.0953432922969455e+73, b 2.956709525056746e+71, iteration 78
# m -1.7747317163096014e+74, b -2.504299027908056e+72, iteration 79
# m 1.5031773917210986e+75, b 2.121112530004404e+73, iteration 80
# m -1.273173995943435e+76, b -1.7965579648449482e+74, iteration 81
# m 1.0783637599090045e+77, b 1.5216639736889034e+75, iteration 82
# m -9.133617261978298e+77, b -1.2888319186642775e+76, iteration 83
# m 7.736068976886559e+78, b 1.0916258407176056e+77, iteration 84
# m -6.552361621750738e+79, b -9.245945564084275e+77, iteration 85
# m 5.549775079625887e+80, b 7.831209759363375e+78, iteration 86
# m -4.700595787051052e+81, b -6.632944772395721e+79, iteration 87
# m 3.9813506738964224e+82, b 5.618028083215113e+80, iteration 88
# m -3.3721583192074084e+83, b -4.758405297620753e+81, iteration 89
# m 2.8561793876525963e+84, b 4.030314665758547e+82, iteration 90
# m -2.419151155503564e+85, b -3.4136302582611655e+83, iteration 91
# m 2.0489932594829217e+86, b 2.8913056439782975e+84, iteration 92
# m -1.735473770564174e+87, b -2.4489026914001495e+85, iteration 93
# m 1.4699263623133136e+88, b 2.074192468872002e+86, iteration 94
# m -1.2450107557207557e+89, b -1.7568172116571609e+87, iteration 95
# m 1.054509818723813e+90, b 1.4880040119195451e+88, iteration 96
# m -8.931577118313173e+90, b -1.2603223174254442e+89, iteration 97
# m 7.564943294403676e+91, b 1.067478535727581e+90, iteration 98
# m -6.407420133024764e+92, b -9.041420662667186e+90, iteration 99
# m 5.427011302445904e+93, b 7.657979515586899e+91, iteration 100
# m -4.5966162769744745e+94, b -6.486220744412156e+92, iteration 101
# m 3.893281222433439e+95, b 5.493754515745566e+93, iteration 102
# m -3.29756450475994e+96, b -4.6531470124996684e+94, iteration 103
# m 2.7929992830715875e+97, b 3.9411621065118125e+95, iteration 104
# m -2.3656383321624506e+98, b -3.3381190639537626e+96, iteration 105
# m 2.0036685123821077e+99, b 2.8273485291864483e+97, iteration 106
# m -1.6970842300486683e+100, b -2.3947317493296888e+98, iteration 107
# m 1.4374108621669228e+101, b 2.028310302761918e+99, iteration 108
# m -1.217470500339399e+102, b -1.7179555436393693e+100, iteration 109
# m 1.0311835385480336e+103, b 1.4550886251982284e+101, iteration 110
# m -8.734006202828014e+103, b -1.23244336270539e+102, iteration 111
# m 7.397602996887337e+104, b 1.043865381099825e+103, iteration 112
# m -6.265684821913348e+105, b -8.84141995350386e+103, iteration 113
# m 5.306963120902011e+106, b 7.488581210716548e+104, iteration 114
# m -4.494936845229576e+107, b -6.342742324695573e+105, iteration 115
# m 3.8071599109149835e+108, b 5.372229941222095e+106, iteration 116
# m -3.224620742482956e+109, b -4.5502170928484535e+107, iteration 117
# m 2.7312167537381716e+110, b 3.853981646090953e+108, iteration 118
# m -2.3133092390134018e+111, b -3.2642782147143204e+109, iteration 119
# m 1.959346371166035e+112, b 2.7648061774934157e+110, iteration 120
# m -1.6595438852087117e+113, b -2.3417590953639804e+111, iteration 121
# m 1.4056146210098777e+114, b 1.9834430729215145e+112, iteration 122
# m -1.1905394490657067e+115, b -1.6799535149916294e+113, iteration 123
# m 1.0083732472584435e+116, b 1.42290134315562e+114, iteration 124
# m -8.540805653978956e+116, b -1.2051811042903498e+115, iteration 125
# m 7.233964349744711e+117, b 1.0207745611634117e+116, iteration 126
# m -6.127084766177536e+118, b -8.645843359217853e+116, iteration 127
# m 5.189570464671929e+119, b 7.322930080363246e+117, iteration 128
# m -4.395506612942926e+120, b -6.202437718781446e+118, iteration 129
# m 3.7229436455192992e+121, b 5.2533935505573606e+119, iteration 130
# m -3.153290532404097e+122, b -4.4495640340681584e+120, iteration 131
# m 2.6708008845947414e+123, b 3.768729660691872e+121, iteration 132
# m -2.2621376913574953e+124, b -3.1920707616815266e+122, iteration 133
# m 1.916004657695288e+125, b 2.703647293637797e+123, iteration 134
# m -1.6228339514147998e+126, b -2.289958222775853e+124, iteration 135
# m 1.3745217284766152e+127, b 1.9395683284571426e+125, iteration 136
# m -1.1642041260026798e+128, b -1.642792110064735e+126, iteration 137
# m 9.860675309249742e+128, b 1.3914260597551198e+127, iteration 138
# m -8.351878797088514e+129, b -1.178521900552205e+128, iteration 139
# m 7.073945470633691e+130, b 9.981945216159155e+128, iteration 140
# m -5.991550612413491e+131, b -8.45459301619393e+129, iteration 141
# m 5.0747745922187064e+132, b 7.160943235168271e+130, iteration 142
# m -4.298275826707021e+133, b -6.065236720334401e+131, iteration 143
# m 3.640590285681342e+134, b 5.137185879791207e+132, iteration 144
# m -3.083538181948501e+135, b -4.3511374708671104e+133, iteration 145
# m 2.6117214444400984e+136, b 3.68536349149066e+134, iteration 146
# m -2.212098083714339e+137, b -3.121460573321204e+135, iteration 147
# m 1.8736216844218978e+138, b 2.6438412746249006e+136, iteration 148
# m -1.586936059562753e+139, b -2.23930321118009e+137, iteration 149
# m 1.3441166261467531e+140, b 1.8966641151000655e+138, iteration 150
# m -1.1384513533468479e+141, b -1.6064527338450758e+139, iteration 151
# m 9.642552280993527e+141, b 1.3606470252336506e+140, iteration 152
# m -8.167131095971032e+142, b -1.152452411622417e+141, iteration 153
# m 6.917466288490198e+143, b 9.761139637418127e+141, iteration 154
# m -5.8590145413490594e+144, b -8.267573225608575e+142, iteration 155
# m 4.9625180613973254e+145, b 7.002539619326608e+143, iteration 156
# m -4.203195833684398e+146, b -5.931070676018033e+144, iteration 157
# m 3.560058623006265e+147, b 5.023548780335756e+145, iteration 158
# m -3.015328788078759e+148, b -4.254888152058861e+146, iteration 159
# m 2.5539488708022084e+149, b 3.603841423297749e+147, iteration 160
# m -2.1631653770094626e+150, b -3.0524123173466356e+148, iteration 161
# m 1.8321762435372103e+151, b 2.585358194413448e+149, iteration 162
# m -1.5518322468820834e+152, b -2.1897687135632508e+150, iteration 163
# m 1.3143840997598804e+153, b 1.854708964220851e+151, iteration 164
# Using gradient descent function: Coef -1.1132682447942868e+154 Intercept -1.5709172026499592e+152
# Using sklearn: Coef [1.01773624] Intercept 1.9152193111569176
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4748\2462587491.py:9: RuntimeWarning: overflow encountered in scalar power
#   cost = (1/n)*sum([value**2 for value in (y-y_predicted)])
